# %% [markdown]
# <h1 style="text-align:center; color=blue">Examples showing how to use PySTL</h1>
# <hr>

# %% [markdown]
# ### 1. Create a circle stl file
# #### Excercise: Create and display a circle:
#
# * Step: 1.0: Import the required library:
#     - PySTL
# * Step: 2.0: Create circle from the Shape class
# * Step:3.0: Set the desired attributes on the circle, here we set:
#     - radius = 10
#     - resolution = 20 (the number of points to be used to create the circle. The more the finer
#     the circle.)
# * Step 4.0: Call the create method on the shape object (circle here).
# * Step 5.0: Visualize the created circle (in this example using pyvista).
#
# **Note: Look for implementation of this below.**

# %%
# step 1.0: import PySTL
from PySTL import shapes
# step 2.0: create a circle object from the shaped module
circle=shapes.Circle()
# set correct mode for display of the shape created -> None uses matplotlib backend
#                                                   -> "pv" uses the pyvista backend to display stl.
circle.mode = "pv"
# set attributes like radius of circle, resolution (how many points to be used to create a circle)
circle.radius = 10.0
circle.resolution = 20
# step 3.0: Once all desired attributes are set, call the create method on the object
circle.create()
# step 4.0: After creating export method on the object can be called to create the stl file
circle.export('Results/circle.stl', 'circle')
# step 5.0: Optionally, the shape can be visulaized by calling the visualize method appropriately
# here is an exaple that uses pyvista backend because the mode is set as pv.
circle.visualize().plot(color='teal', text=f'{circle.name}',jupyter_backend="static")
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %% [markdown]
# ### 1. Create a Cylinder stl file
# #### Excercise: Create and display a cylinder:
#
# * Step: 1.0: Import the required library:
#     - PySTL
# * Step: 2.0: Create cylinder from the Shape class
# * Step:3.0: Set the desired attributes on the cylinder, here we set:
#     - radius = 10
#     - resolution = 20 (the number of points to be used to create the cylinder. The more the finer
#     the cylinder.)
# * Step 4.0: Call the create method on the shape object (cylinder here).
# * Step 5.0: Visualize the created cylinder (in this example using pyvista).
#
# **Note: Look for implementation of this below.**

# %%
# cylinder
# step 1.0: create a cylinder object
cyl = shapes.Cylinder()
# step 2.0: Set appropriate properties on the object
cyl.mode = "pv"
cyl._height = 10.00
cyl._top_circle_radius = 4.00
cyl._base_circle_radius = 4.00
cyl.resolution = 20
cyl.close = True
# step 3.0: call create method on the object
cyl.create()
# step 4.0: call export method to write the stl file
cyl.export('Results/cyl.stl', 'cyl')
# step 5.0 Call the visualize method to plot using pyvista
cyl.visualize().plot(jupyter_backend='static', text=f'{cyl.name}')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x768>

# %%
# sphere 
sphere = shapes.Sphere()
sphere.radius = 10
sphere.resolution_latitude = 200
sphere.resoultion_longitude = 200
sphere.create()
sphere.export('Results/sphere.stl', 'sphere')
sphere.visualize().plot(color='magenta', jupyter_backend='static', text=f'{sphere.name}')
# Out:
# /Users/sudofr/Documents/Projects/PySTL/PySTL/utilities.py:64: RuntimeWarning: invalid value encountered in divide
#   n = n / np.linalg.norm(n)
# <PIL.Image.Image image mode=RGB size=1024x768>
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
